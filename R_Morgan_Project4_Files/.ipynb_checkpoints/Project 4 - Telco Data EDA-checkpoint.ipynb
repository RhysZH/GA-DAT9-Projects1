# %% [markdown]
# ### Project 4 EDA
#
# The following is EDA for Project 4 for Rhys Morgan, as per the project brief. EDA is focused on determining preparation required for Telecom customer data, as well as general characteristics that will help in feature selection. Please see comments and notes below cells (in markup) for objectives of each cell.

# %% [markdown]
# #### Key findings and next steps
#
# 1. Our 3 'Total_X_minutes' features showed strong positive correlation with 'total_XXX_charge' features. Therefore, I have removed the 'minutes' features to eliminate correlating features.
#
#
# 2. Once we converted categorical features to numerical features (through dummy variables and ordinal replacement values), there is a discrepancy in the scaling of each feature. We therefore need to scale our features using __StandardScaler__.
#
#
# 3. Our target feature ('churn') was heavily imbalanced, in that there were far more customers who did not churn vs those who did. We therefore have to re-sample our data so that both '1' and '0' classes are equally represented in the data. We can accomplish this through __SMOTE-Tomek__.
#
# Cleaned dataset has been exported to csv for ease of import in modelling phase.

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np
import csv

# %matplotlib inline

TELDATA = r"https://raw.githubusercontent.com/RhysZH/GA-DAT9-Projects1/master/R_Morgan_Project4_Files/Telecom_Data_SingTel.csv"

df= pd.read_csv(TELDATA)
df.head()
# Out:
#   State  Account Length  Area Code Phone Number International Plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   Voice mail Plan  Num of Voice mail Messages  Total Day Minutes  \
# 0             yes                          25              265.1
# 1             yes                          26              161.6
# 2              no                           0              243.4
# 3              no                           0              299.4
# 4              no                           0              166.7
#
#    Total Day Calls  Total day Charge   ...     Total Eve Calls  \
# 0              110             45.07   ...                  99
# ...

# %%
df.columns = map(str.lower, df.columns)
df.columns = df.columns.str.replace(' ', '_')
df.rename(columns={'total_night_calls_':'total_night_calls','total_intl__calls':'total_intl_calls', 'number_customer_service_calls_':'number_customer_service_calls'}, inplace = True)

df.dtypes
# Out:
# state                             object
# account_length                     int64
# area_code                          int64
# phone_number                      object
# international_plan                object
# voice_mail_plan                   object
# num_of_voice_mail_messages         int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_international_minutes      float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churn                             object
# dtype: object

# %%
df.shape
# Out:
# (5000, 21)

# %%
df.head()
# Out:
#   state  account_length  area_code phone_number international_plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice_mail_plan  num_of_voice_mail_messages  total_day_minutes  \
# 0             yes                          25              265.1
# 1             yes                          26              161.6
# 2              no                           0              243.4
# 3              no                           0              299.4
# 4              no                           0              166.7
#
#    total_day_calls  total_day_charge   ...     total_eve_calls  \
# 0              110             45.07   ...                  99
# ...

# %%
df.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# num_of_voice_mail_messages       0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_international_minutes      0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
#upon conversion, all features are object types. We need to rectify this to allow calculations
df.describe()
# Out:
#        account_length    area_code  num_of_voice_mail_messages  \
# count      5000.00000  5000.000000                 5000.000000
# mean        100.25860   436.911400                    7.755200
# std          39.69456    42.209182                   13.546393
# min           1.00000   408.000000                    0.000000
# 25%          73.00000   408.000000                    0.000000
# 50%         100.00000   415.000000                    0.000000
# 75%         127.00000   415.000000                   17.000000
# max         243.00000   510.000000                   52.000000
#
#        total_day_minutes  total_day_calls  total_day_charge  \
# count        5000.000000      5000.000000       5000.000000
# mean          180.288900       100.029400         30.649668
# std            53.894699        19.831197          9.162069
# min             0.000000         0.000000          0.000000
# 25%           143.700000        87.000000         24.430000
# ...

# %%
#give columns clearer names
#df.rename(columns={'housing':'has_housing_loan','loan':'has_personal_loan','contact':'contact_method','month':'last_comm_month','day_of_week':'last_comm_weekday','duration':'last_comm_duration','campaign':'contacts_during_campaign','pdays':'prev_camp_days_passed','previous':'num_prev_contacts','poutcome':'prev_camp_outcome','emp.var.rate':'emp_var_rate','cons.price.idx':'cons_price_idx','cons.conf.idx':'cons_conf_idx','euribor3m':'euribor_3m','nr.employed':'num_employed','y':'converted'}, inplace=True)
#df.head()

# %%
#no nulls in data
df.corr()
# Out:
#                                account_length  area_code  \
# account_length                       1.000000  -0.018054
# area_code                           -0.018054   1.000000
# num_of_voice_mail_messages          -0.014575  -0.003399
# total_day_minutes                   -0.001017  -0.019118
# total_day_calls                      0.028240  -0.019314
# total_day_charge                    -0.001019  -0.019119
# total_eve_minutes                   -0.009591   0.007098
# total_eve_calls                      0.009143  -0.012300
# total_eve_charge                    -0.009587   0.007114
# total_night_minutes                  0.000668   0.002084
# total_night_calls                   -0.007825   0.014657
# total_night_charge                   0.000656   0.002070
# total_international_minutes          0.001291  -0.004154
# total_intl_calls                     0.014277  -0.013623
# total_intl_charge                    0.001292  -0.004219
# ...

# %%
dg = df.loc[df['area_code']==415]
subs_dist = dg['churn'].value_counts()
subs_dist.plot.bar(x = 'churn', title='Distribution')

# %%
#check target distribution - quite imbalanced
subs_dist = df['churn'].value_counts()
subs_dist.plot.bar(x = 'churn', title='Distribution')

# %% [markdown]
# 1. Data is unbalanced, with roughly 10% of instances converting.

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),vmin=-1,vmax=1,center=0,cmap='RdBu')

# %% [markdown]
# 1. Correlation between charges and minutes at different times during the day.

# %%
df.describe(include='all')
# Out:
#        state  account_length    area_code phone_number international_plan  \
# count   5000      5000.00000  5000.000000         5000               5000
# unique    51             NaN          NaN         5000                  2
# top       WV             NaN          NaN     396-7504                 no
# freq     158             NaN          NaN            1               4527
# mean     NaN       100.25860   436.911400          NaN                NaN
# std      NaN        39.69456    42.209182          NaN                NaN
# min      NaN         1.00000   408.000000          NaN                NaN
# 25%      NaN        73.00000   408.000000          NaN                NaN
# 50%      NaN       100.00000   415.000000          NaN                NaN
# 75%      NaN       127.00000   415.000000          NaN                NaN
# max      NaN       243.00000   510.000000          NaN                NaN
#
#        voice_mail_plan  num_of_voice_mail_messages  total_day_minutes  \
# ...

# %%
sns.boxplot(y=df['total_eve_calls'])

# %%
#
df.nunique()
# Out:
# state                              51
# account_length                    218
# area_code                           3
# phone_number                     5000
# international_plan                  2
# voice_mail_plan                     2
# num_of_voice_mail_messages         48
# total_day_minutes                1961
# total_day_calls                   123
# total_day_charge                 1961
# total_eve_minutes                1879
# total_eve_calls                   126
# total_eve_charge                 1659
# total_night_minutes              1853
# total_night_calls                 131
# total_night_charge               1028
# total_international_minutes       170
# total_intl_calls                   21
# total_intl_charge                 170
# number_customer_service_calls      10
# churn                               2
# dtype: int64

# %% [markdown]
# 'international_plan' & 'voice_mail_plan','can be converted to ordinal values. 'phone_number' and 'state' can be removed as there are too many classes for meaningful use. Other categorical features will need dummy variables via 'get_dummies' for classification modelling.

# %% [markdown]
# 1. created maps for ordinal features, then assigned features to desired maps. Some of the columns share categories (yes, no).
# 2. Other categorical features will have to be converted to dummy variables.

# %%
print(set(df['international_plan']))
# Out:
# {' no', ' yes'}

# %%
df.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# num_of_voice_mail_messages       0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_international_minutes      0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
#function to get standard deviation of feature
def telecom_std(col1):
    print(df[col1].std())
    
telecom_std('total_day_calls')
# Out:
# 19.831197415138462

# %%
conversion_map = {' False.':0,' True.':1}
yn_map = {' no':'0',' yes':'1'}
df['international_plan_n'] = df['international_plan'].map(yn_map)
df['voice_mail_plan_n'] = df['voice_mail_plan'].map(yn_map)
df['area_code'] = df.area_code.astype(str)
df['international_plan_n'] = df.international_plan_n.astype(int)
df['voice_mail_plan_n'] = df.voice_mail_plan_n.astype(int)
df = pd.get_dummies(df, columns=['area_code'])
df['churn_n'] = df['churn'].map(conversion_map)
df.drop(['state','phone_number','international_plan','voice_mail_plan','churn'],axis=1, inplace=True)
         #'total_international_minutes','total_day_minutes','total_eve_minutes',
         #'total_night_minutes'],axis=1, inplace=True)
df.dtypes
# Out:
# account_length                     int64
# num_of_voice_mail_messages         int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_international_minutes      float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# international_plan_n               int64
# voice_mail_plan_n                  int64
# area_code_408                      uint8
# area_code_415                      uint8
# area_code_510                      uint8
# churn_n                            int64
# dtype: object

# %%
feature_names = ['account_length','num_of_voice_mail_messages','total_day_minutes','total_day_calls','total_day_charge',
                 'total_eve_minutes','total_eve_calls','total_eve_charge','total_night_minutes','total_night_calls','total_night_charge',
                 'total_international_minutes','total_intl_calls','total_intl_charge','number_customer_service_calls','international_plan_n',
                 'voice_mail_plan_n','area_code_408','area_code_415','area_code_510']

X = df[feature_names]
y = df['churn_n']

X.shape
# Out:
# (5000, 20)

# %%
sns.heatmap(df.corr(),vmin=-1,vmax=1,center=0,cmap='RdBu')

# %% [markdown]
# Target feature shows correlation with multiple features, namely internationa_plan_n, total charges and customer service calls.indicating an existing relationship.

# %% [markdown]
# ### Feature Selector Library - exploratory feature selection

# %%
from feature_selector import FeatureSelector

fs = FeatureSelector(data = X, labels = y)
#flag features that have majority missing values
fs.identify_missing(missing_threshold=0.6)
missing_features = fs.ops['missing']
missing_features[:10]
# Out:
# 0 features with greater than 0.60 missing values.
# []

# %%
#flag co-linear features
fs.identify_collinear(correlation_threshold=0.7)
correlated_features = fs.ops['collinear']
correlated_features[:5]
# Out:
# 5 features with a correlation magnitude greater than 0.70.
# ['total_day_charge',
#  'total_eve_charge',
#  'total_night_charge',
#  'total_intl_charge',
#  'voice_mail_plan_n']

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)


one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [68]	valid_0's binary_logloss: 0.136685	valid_0's auc: 0.951115
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [125]	valid_0's binary_logloss: 0.142226	valid_0's auc: 0.918394
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [101]	valid_0's binary_logloss: 0.120434	valid_0's auc: 0.956309
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [10]	valid_0's binary_logloss: 0.259124	valid_0's auc: 0.929282
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [99]	valid_0's binary_logloss: 0.140632	valid_0's auc: 0.938524
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# ...

# %%
#flag features with cumulative importance
fs.identify_low_importance(cumulative_importance = 0.99)
low_importance_features = fs.ops['low_importance']
low_importance_features[:5]
# Out:
# 15 features required for cumulative importance of 0.99 after one hot encoding.
# 5 features do not contribute to cumulative importance of 0.99.
# ['area_code_415',
#  'area_code_510',
#  'area_code_408',
#  'total_intl_charge',
#  'total_day_charge']

# %% [markdown]
# While we will take these features into consideration, we shall leave them in the cleaned dataset to see if other feature selection methods retain or remove them.

# %% [markdown]
# #### Converted cleaned dataset to csv

# %%
#converted to csv for easy importing into modelling notebook. The code below is commented to avoid creating a new file.
#df.to_csv(r"/Users/meisan/Documents/GitHub/GA-DAT9-Projects1/R_Morgan_Project4_Files/telecom_data.csv", sep="," )
