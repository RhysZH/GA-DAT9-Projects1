# %% [markdown]
# #### Project 4 EDA
#
# The following is EDA for Project 4 for Rhys Morgan, as per the project brief. EDA is focused on determining preparation required for bank marketing data, as well as general characteristics that will help in feature selection. Please see comments and notes below cells (in markup) for objectives of each cell.

# %% [markdown]
# #### Key findings and next steps
#
# 1. 'education','default','has_housing_loan','has_personal_loan','contact_method' and 'prev_campaign_outcome' can be converted to ordinal values. Unsure regarding the last comm month and weekday, though these will likely require dummy variables too.
# 2. Other categorical features will need dummy variables for classification modelling.
# 3. 'emp_var_rate' correlates with all 'index' metrics except confidence index, so some of these need not be included.
# 4. No nulls present.

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np
import csv

BANKDATA = r"/Users/meisan/Documents/GitHub/GA-DAT9-Projects1/R_Morgan_Project4_Files/Bank_Marketing_Data.csv"
#extra data source for other laptop
#BANKDATA = r"C:\Users\rhys.morgan\Documents\EDA\Bank_Marketing_Data.csv"
with open(BANKDATA, 'r') as b:
    data = b.read()
    new_data = data.replace('"','')
sep_data = new_data.split('\n')

#split each row into list, append each new list as an element of 'bank_data'
bank_data = []
for row in sep_data:
    bank_data.append(row.split(';'))
    
dl = pd.DataFrame(bank_data)
dl.columns = dl.iloc[0]
dh = dl.drop(dl.index[0])
df = dh.drop(dh.index[-1])

# %% [markdown]
# 1. Data was downloaded in a strange format, with ';' separating columns and '\n' separating rows. Every element was also enclosed in quotes, requiring removal for clean, useable data.
# 2. To create a DataFrame of organised data, first the data is read using python, then the quote marks around all elements are removed.
# 3. we then create a list, 'sep_data', with each element being a row of data (separated by '\n')
# 4. We then separate each row of 'sep_data' into a sublist, with each element separated by ';'. Each sublist is appended to a list, 'bank_data', which is now a list of lists.
# 5. We then convert 'bank_data' into a DataFrame, assign the first row as column names, then remove said row. This data also had an extra last row, so that was deleted as well.

# %%
#upon conversion, all features are object types. We need to rectify this to allow calculations
df.dtypes
# Out:
# 0
# age               object
# job               object
# marital           object
# education         object
# default           object
# housing           object
# loan              object
# contact           object
# month             object
# day_of_week       object
# duration          object
# campaign          object
# pdays             object
# previous          object
# poutcome          object
# emp.var.rate      object
# cons.price.idx    object
# cons.conf.idx     object
# euribor3m         object
# nr.employed       object
# y                 object
# dtype: object

# %%
#give columns clearer names
df.rename(columns={'housing':'has_housing_loan','loan':'has_personal_loan','contact':'contact_method','month':'last_comm_month','day_of_week':'last_comm_weekday','duration':'last_comm_duration','campaign':'contacts_during_campaign','pdays':'prev_camp_days_passed','previous':'num_prev_contacts','poutcome':'prev_camp_outcome','emp.var.rate':'emp_var_rate','cons.price.idx':'cons_price_idx','cons.conf.idx':'cons_conf_idx','euribor3m':'euribor_3m','nr.employed':'num_employed','y':'converted'}, inplace=True)
df.head()
# Out:
# 0 age        job  marital    education  default has_housing_loan  \
# 1  56  housemaid  married     basic.4y       no               no
# 2  57   services  married  high.school  unknown               no
# 3  37   services  married  high.school       no              yes
# 4  40     admin.  married     basic.6y       no               no
# 5  56   services  married  high.school       no               no
#
# 0 has_personal_loan contact_method last_comm_month last_comm_weekday  \
# 1                no      telephone             may               mon
# 2                no      telephone             may               mon
# 3                no      telephone             may               mon
# 4                no      telephone             may               mon
# 5               yes      telephone             may               mon
#
# 0    ...    contacts_during_campaign prev_camp_days_passed num_prev_contacts  \
# 1    ...                           1                   999                 0
# ...

# %%
#no nulls in data
df.isnull().sum()
# Out:
# 0
# age                         0
# job                         0
# marital                     0
# education                   0
# default                     0
# has_housing_loan            0
# has_personal_loan           0
# contact_method              0
# last_comm_month             0
# last_comm_weekday           0
# last_comm_duration          0
# contacts_during_campaign    0
# prev_camp_days_passed       0
# num_prev_contacts           0
# prev_camp_outcome           0
# emp_var_rate                0
# cons_price_idx              0
# cons_conf_idx               0
# euribor_3m                  0
# num_employed                0
# converted                   0
# dtype: int64

# %%
#redefine the data types of numeric columns
df['age'] = df.age.astype(int)
df['last_comm_duration'] = df.last_comm_duration.astype(int)
df['contacts_during_campaign'] = df.contacts_during_campaign.astype(int)
df['prev_camp_days_passed'] = df.prev_camp_days_passed.astype(int)
df['num_prev_contacts'] = df.num_prev_contacts.astype(int)
df['emp_var_rate'] = df.emp_var_rate.astype(float)
df['cons_price_idx'] = df.cons_price_idx.astype(float)
df['cons_conf_idx'] = df.cons_conf_idx.astype(float)
df['euribor_3m'] = df.euribor_3m.astype(float)
df['num_employed'] = df.num_employed.astype(float)
df.dtypes
# Out:
# 0
# age                           int64
# job                          object
# marital                      object
# education                    object
# default                      object
# has_housing_loan             object
# has_personal_loan            object
# contact_method               object
# last_comm_month              object
# last_comm_weekday            object
# last_comm_duration            int64
# contacts_during_campaign      int64
# prev_camp_days_passed         int64
# num_prev_contacts             int64
# prev_camp_outcome            object
# emp_var_rate                float64
# cons_price_idx              float64
# cons_conf_idx               float64
# euribor_3m                  float64
# num_employed                float64
# converted                    object
# dtype: object

# %%
#select all integer-type features for comparison
ind_predictors = ['emp_var_rate','cons_price_idx','cons_conf_idx','euribor_3m','num_employed']               
dg = df[ind_predictors]
sns.pairplot(dg)

# %%
dg.corr()
# Out:
# 0               emp_var_rate  cons_price_idx  cons_conf_idx  euribor_3m  \
# 0
# emp_var_rate        1.000000        0.775334       0.196041    0.972245
# cons_price_idx      0.775334        1.000000       0.058986    0.688230
# cons_conf_idx       0.196041        0.058986       1.000000    0.277686
# euribor_3m          0.972245        0.688230       0.277686    1.000000
# num_employed        0.906970        0.522034       0.100513    0.945154
#
# 0               num_employed
# 0
# emp_var_rate        0.906970
# cons_price_idx      0.522034
# cons_conf_idx       0.100513
# euribor_3m          0.945154
# num_employed        1.000000

# %% [markdown]
# 'emp_var_rate' correlates with all metrics here except confidence index. Many of these metrics correlate with each other, so further feature selection will have to be done.

# %%
#select all integer-type features for comparison
predictors = ['age','last_comm_duration','contacts_during_campaign','prev_camp_days_passed','num_prev_contacts']
dl = df[predictors]
sns.pairplot(dl)

# %%
sns.heatmap(df.corr(),vmin=-1,vmax=1,center=0,cmap='RdBu')

# %%
dl.corr()
# Out:
# 0                              age  last_comm_duration  \
# 0
# age                       1.000000           -0.000866
# last_comm_duration       -0.000866            1.000000
# contacts_during_campaign  0.004594           -0.071699
# prev_camp_days_passed    -0.034369           -0.047577
# num_prev_contacts         0.024365            0.020640
#
# 0                         contacts_during_campaign  prev_camp_days_passed  \
# 0
# age                                       0.004594              -0.034369
# last_comm_duration                       -0.071699              -0.047577
# contacts_during_campaign                  1.000000               0.052584
# prev_camp_days_passed                     0.052584               1.000000
# num_prev_contacts                        -0.079141              -0.587514
#
# 0                         num_prev_contacts
# 0
# age                                0.024365
# last_comm_duration                 0.020640
# ...

# %% [markdown]
# 1. no correlation amongst integer features

# %%
df.describe(include='all')
# Out:
# 0               age     job  marital          education default  \
# count   41188.00000   41188    41188              41188   41188
# unique          NaN      12        4                  8       3
# top             NaN  admin.  married  university.degree      no
# freq            NaN   10422    24928              12168   32588
# mean       40.02406     NaN      NaN                NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN
#
# 0      has_housing_loan has_personal_loan contact_method last_comm_month  \
# count             41188             41188          41188           41188
# ...

# %%
subs_dist = df['converted'].value_counts()
subs_dist.plot.bar(x = 'converted', title='Distribution')

# %% [markdown]
# 1. Data is unbalanced, with roughly 10% of instances converting.

# %%
df.corr()
# Out:
# 0                              age  last_comm_duration  \
# 0
# age                       1.000000           -0.000866
# last_comm_duration       -0.000866            1.000000
# contacts_during_campaign  0.004594           -0.071699
# prev_camp_days_passed    -0.034369           -0.047577
# num_prev_contacts         0.024365            0.020640
# emp_var_rate             -0.000371           -0.027968
# cons_price_idx            0.000857            0.005312
# cons_conf_idx             0.129372           -0.008173
# euribor_3m                0.010767           -0.032897
# num_employed             -0.017725           -0.044703
#
# 0                         contacts_during_campaign  prev_camp_days_passed  \
# 0
# age                                       0.004594              -0.034369
# last_comm_duration                       -0.071699              -0.047577
# contacts_during_campaign                  1.000000               0.052584
# ...

# %%
subs_dist.plot.bar(x='converted', title='Distribution')

# %%
sns.boxplot(y=df['age'])

# %%
#'has_housing_loan','has_personal_loan','contact_method',
df.nunique()
# Out:
# 0
# age                           78
# job                           12
# marital                        4
# education                      8
# default                        3
# has_housing_loan               3
# has_personal_loan              3
# contact_method                 2
# last_comm_month               10
# last_comm_weekday              5
# last_comm_duration          1544
# contacts_during_campaign      42
# prev_camp_days_passed         27
# num_prev_contacts              8
# prev_camp_outcome              3
# emp_var_rate                  10
# cons_price_idx                26
# cons_conf_idx                 26
# euribor_3m                   316
# num_employed                  11
# converted                      2
# dtype: int64

# %% [markdown]
# 1.'education', 'default','has_housing_loan','has_personal_loan',and 'prev_camp_outcome' can be converted to ordinal values. Unsure regarding education, the last comm month and weekday. Other categorical features will need dummy variables via 'get_dummies' for classification modelling.

# %%
#check all unique values for ordinal features
print(set(df['education']))
print(set(df['default']))
print(set(df['has_housing_loan']))
print(set(df['has_personal_loan']))
print(set(df['prev_camp_outcome']))
print(set(df['converted']))
# Out:
# {'basic.4y', 'unknown', 'professional.course', 'illiterate', 'high.school', 'university.degree', 'basic.9y', 'basic.6y'}
# {'unknown', 'yes', 'no'}
# {'yes', 'no', 'unknown'}
# {'yes', 'no', 'unknown'}
# {'success', 'failure', 'nonexistent'}
# {'yes', 'no'}

# %%
#map categories to numerical, then assign
education_map = {'basic.4y':2, 'unknown':0, 'professional.course':6, 'illiterate':1, 'high.school':5, 'university.degree':7, 'basic.9y':4, 'basic.6y':3}
default_map = {'unknown':0,'no':1,'yes':2}
conversion_map = {'no':0,'yes':1}
outcome_map = {'nonexistent':0,'failure':1,'success':2}
df['education_num'] = df['education'].map(education_map)
df['default_num'] = df['default'].map(default_map)
df['has_housing_num'] = df['has_housing_loan'].map(default_map)
df['has_personal_num'] = df['has_personal_loan'].map(default_map)
df['prev_outcome_num'] = df['prev_camp_outcome'].map(outcome_map)
df['converted_num'] = df['converted'].map(conversion_map)
df.head(3)
# Out:
# 0  age        job  marital    education  default has_housing_loan  \
# 1   56  housemaid  married     basic.4y       no               no
# 2   57   services  married  high.school  unknown               no
# 3   37   services  married  high.school       no              yes
#
# 0 has_personal_loan contact_method last_comm_month last_comm_weekday  \
# 1                no      telephone             may               mon
# 2                no      telephone             may               mon
# 3                no      telephone             may               mon
#
# 0      ...        cons_conf_idx  euribor_3m  num_employed  converted  \
# 1      ...                -36.4       4.857        5191.0         no
# 2      ...                -36.4       4.857        5191.0         no
# 3      ...                -36.4       4.857        5191.0         no
#
# 0 education_num  default_num  has_housing_num  has_personal_num  \
# 1             2            1                1                 1
# ...

# %% [markdown]
# 1. created maps for ordinal features, then assigned features to desired maps. Some of the columns share categories (yes, no, unknown).
# 2. Other categorical features will have to be converted to dummy variables.

# %%
df.shape
# Out:
# (41188, 27)

# %%
def corr_cols(x,y):
    print(df[x].corr(df[y]))

corr_cols('contacts_during_campaign','last_comm_duration')
# Out:
# -0.07169922626415345

# %%
def bank_std(col1):
    print(df[col1].std())
    
bank_std('contacts_during_campaign')
# Out:
# 2.7700135429021127

# %%
pivot_items = pd.pivot_table(df, values='num_prev_contacts', index=['education'], aggfunc=np.sum)
pivot_items
# Out:
# 0                    num_prev_contacts
# education
# basic.4y                           614
# basic.6y                           296
# basic.9y                           855
# high.school                       1769
# illiterate                           2
# professional.course                855
# university.degree                 2341
# unknown                            392

# %%
pivot_items = pd.pivot_table(df, values='contacts_during_campaign', index=['job'], aggfunc=np.mean)
pivot_items
# Out:
# 0              contacts_during_campaign
# job
# admin.                         2.623489
# blue-collar                    2.558461
# entrepreneur                   2.535714
# housemaid                      2.639623
# management                     2.476060
# retired                        2.476744
# self-employed                  2.660802
# services                       2.587805
# student                        2.104000
# technician                     2.577339
# unemployed                     2.564103
# unknown                        2.648485

# %%
df.pivot_table(values='contacts_during_campaign',index=['job'], columns='converted',aggfunc=np.sum)
# Out:
# converted         no   yes
# job
# admin.         24559  2783
# blue-collar    22300  1376
# entrepreneur    3436   256
# housemaid       2597   201
# management      6574   666
# retired         3417   843
# self-employed   3466   315
# services        9550   721
# student         1343   498
# technician     15885  1494
# unemployed      2322   278
# unknown          785    89

# %% [markdown]
# 1. 'retired' and 'student' occupations have a higher conversion rate than others
