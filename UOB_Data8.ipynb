# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %matplotlib inline


DATA_FILE = r"C:\Users\rhys.morgan\Documents\EDA\dealsmod.json"

# %%
df = pd.read_json(r"C:\Users\rhys.morgan\Documents\EDA\dealsdata1.json")
df
# Out:
#     campaigns  cardBrands  categories dealCategoryTags dealCountry  \
# 0         NaN         NaN         NaN         [Dining]          SG
# 1         NaN         NaN         NaN         [Dining]          SG
# 2         NaN         NaN         NaN         [Dining]          SG
# 3         NaN         NaN         NaN         [Dining]          SG
# 4         NaN         NaN         NaN         [Dining]          SG
# 5         NaN         NaN         NaN         [Dining]          SG
# 6         NaN         NaN         NaN         [Dining]          SG
# 7         NaN         NaN         NaN         [Dining]          SG
# 8         NaN         NaN         NaN         [Dining]          SG
# 9         NaN         NaN         NaN         [Dining]          SG
# 10        NaN         NaN         NaN         [Dining]          SG
# 11        NaN         NaN         NaN         [Dining]          SG
# 12        NaN         NaN         NaN         [Dining]          SG
# ...

# %%
writer = pd.ExcelWriter('UDATA.xlsx')
df.to_excel(writer,'Sheet1')

# %%
dl = df['dealShortDescription'].value_counts()
dl.plot.bar(x='dealShortDescription', title='Deal Types')
